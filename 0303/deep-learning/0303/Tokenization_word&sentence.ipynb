# %%
# 로컬환경에서 진행 (주피터)
# !pip install konlpy
# Out:
# Requirement already satisfied: konlpy in c:\ai\envs\ai\lib\site-packages (0.6.0)
# Requirement already satisfied: JPype1>=0.7.0 in c:\ai\envs\ai\lib\site-packages (from konlpy) (1.6.0)
# Requirement already satisfied: lxml>=4.1.0 in c:\ai\envs\ai\lib\site-packages (from konlpy) (6.0.2)
# Requirement already satisfied: numpy>=1.6 in c:\ai\envs\ai\lib\site-packages (from konlpy) (2.2.6)
# Requirement already satisfied: packaging in c:\ai\envs\ai\lib\site-packages (from JPype1>=0.7.0->konlpy) (25.0)

# %%
pip install kss
# Out:
# Requirement already satisfied: kss in c:\ai\envs\ai\lib\site-packages (6.0.6)
# Requirement already satisfied: emoji==1.2.0 in c:\ai\envs\ai\lib\site-packages (from kss) (1.2.0)
# Requirement already satisfied: pecab in c:\ai\envs\ai\lib\site-packages (from kss) (1.0.8)
# Requirement already satisfied: networkx in c:\ai\envs\ai\lib\site-packages (from kss) (3.4.2)
# Requirement already satisfied: jamo in c:\ai\envs\ai\lib\site-packages (from kss) (0.4.1)
# Requirement already satisfied: hangul-jamo in c:\ai\envs\ai\lib\site-packages (from kss) (1.0.1)
# Requirement already satisfied: tossi in c:\ai\envs\ai\lib\site-packages (from kss) (0.3.1)
# Requirement already satisfied: distance in c:\ai\envs\ai\lib\site-packages (from kss) (0.1.3)
# Requirement already satisfied: pyyaml>=6.0.2 in c:\ai\envs\ai\lib\site-packages (from kss) (6.0.3)
# Requirement already satisfied: unidecode in c:\ai\envs\ai\lib\site-packages (from kss) (1.4.0)
# Requirement already satisfied: cmudict in c:\ai\envs\ai\lib\site-packages (from kss) (1.1.3)
# Requirement already satisfied: koparadigm in c:\ai\envs\ai\lib\site-packages (from kss) (0.10.0)
# Requirement already satisfied: kollocate in c:\ai\envs\ai\lib\site-packages (from kss) (0.0.2)
# Requirement already satisfied: bs4 in c:\ai\envs\ai\lib\site-packages (from kss) (0.0.2)
# Requirement already satisfied: numpy in c:\ai\envs\ai\lib\site-packages (from kss) (2.2.6)
# Requirement already satisfied: pytest in c:\ai\envs\ai\lib\site-packages (from kss) (9.0.2)
# Requirement already satisfied: scipy in c:\ai\envs\ai\lib\site-packages (from kss) (1.15.3)
# Requirement already satisfied: beautifulsoup4 in c:\ai\envs\ai\lib\site-packages (from bs4->kss) (4.14.3)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\ai\envs\ai\lib\site-packages (from beautifulsoup4->bs4->kss) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\ai\envs\ai\lib\site-packages (from beautifulsoup4->bs4->kss) (4.15.0)
# Requirement already satisfied: importlib-metadata>=5 in c:\ai\envs\ai\lib\site-packages (from cmudict->kss) (8.7.1)
# Requirement already satisfied: importlib-resources>=5 in c:\ai\envs\ai\lib\site-packages (from cmudict->kss) (6.5.2)
# Requirement already satisfied: zipp>=3.20 in c:\ai\envs\ai\lib\site-packages (from importlib-metadata>=5->cmudict->kss) (3.23.0)
# Requirement already satisfied: whoosh in c:\ai\envs\ai\lib\site-packages (from kollocate->kss) (2.7.4)
# Requirement already satisfied: xlrd==1.2.0 in c:\ai\envs\ai\lib\site-packages (from koparadigm->kss) (1.2.0)
# Requirement already satisfied: pyarrow in c:\ai\envs\ai\lib\site-packages (from pecab->kss) (23.0.1)
# Requirement already satisfied: regex in c:\ai\envs\ai\lib\site-packages (from pecab->kss) (2026.2.28)
# Requirement already satisfied: colorama>=0.4 in c:\ai\envs\ai\lib\site-packages (from pytest->kss) (0.4.6)
# Requirement already satisfied: exceptiongroup>=1 in c:\ai\envs\ai\lib\site-packages (from pytest->kss) (1.3.1)
# Requirement already satisfied: iniconfig>=1.0.1 in c:\ai\envs\ai\lib\site-packages (from pytest->kss) (2.3.0)
# Requirement already satisfied: packaging>=22 in c:\ai\envs\ai\lib\site-packages (from pytest->kss) (25.0)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\ai\envs\ai\lib\site-packages (from pytest->kss) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in c:\ai\envs\ai\lib\site-packages (from pytest->kss) (2.19.2)
# Requirement already satisfied: tomli>=1 in c:\ai\envs\ai\lib\site-packages (from pytest->kss) (2.4.0)
# Requirement already satisfied: bidict in c:\ai\envs\ai\lib\site-packages (from tossi->kss) (0.23.1)
# Requirement already satisfied: six in c:\ai\envs\ai\lib\site-packages (from tossi->kss) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# ntlk 설치
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\ai\envs\ai\lib\site-packages (3.9.3)
# Requirement already satisfied: click in c:\ai\envs\ai\lib\site-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in c:\ai\envs\ai\lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\ai\envs\ai\lib\site-packages (from nltk) (2026.2.28)
# Requirement already satisfied: tqdm in c:\ai\envs\ai\lib\site-packages (from nltk) (4.67.3)
# Requirement already satisfied: colorama in c:\ai\envs\ai\lib\site-packages (from click->nltk) (0.4.6)

# %%
# tensorflow 설치
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\ai\envs\ai\lib\site-packages (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\ai\envs\ai\lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\ai\envs\ai\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\ai\envs\ai\lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\ai\envs\ai\lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\ai\envs\ai\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\ai\envs\ai\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\ai\envs\ai\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\ai\envs\ai\lib\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in c:\ai\envs\ai\lib\site-packages (from tensorflow) (7.34.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\ai\envs\ai\lib\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in c:\ai\envs\ai\lib\site-packages (from tensorflow) (80.10.2)
# Requirement already satisfied: six>=1.12.0 in c:\ai\envs\ai\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\ai\envs\ai\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\ai\envs\ai\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\ai\envs\ai\lib\site-packages (from tensorflow) (2.1.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\ai\envs\ai\lib\site-packages (from tensorflow) (1.78.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\ai\envs\ai\lib\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\ai\envs\ai\lib\site-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\ai\envs\ai\lib\site-packages (from tensorflow) (2.2.6)
# Requirement already satisfied: h5py>=3.11.0 in c:\ai\envs\ai\lib\site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\ai\envs\ai\lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\ai\envs\ai\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\ai\envs\ai\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\ai\envs\ai\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\ai\envs\ai\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2026.2.25)
# Requirement already satisfied: markdown>=2.6.8 in c:\ai\envs\ai\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.10.2)
# Requirement already satisfied: pillow in c:\ai\envs\ai\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (12.1.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\ai\envs\ai\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\ai\envs\ai\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.6)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\ai\envs\ai\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.46.3)
# Requirement already satisfied: rich in c:\ai\envs\ai\lib\site-packages (from keras>=3.10.0->tensorflow) (14.3.3)
# Requirement already satisfied: namex in c:\ai\envs\ai\lib\site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\ai\envs\ai\lib\site-packages (from keras>=3.10.0->tensorflow) (0.19.0)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\ai\envs\ai\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\ai\envs\ai\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\ai\envs\ai\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\ai\envs\ai\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)

# %%
from nltk.tokenize import word_tokenize
from nltk.tokenize import WordPunctTokenizer
from tensorflow.keras.preprocessing.text import text_to_word_sequence

# import warnings
# warnings.filterwarnings("ignore", category=RuntimeWarning)

# %%
# NLTK 내부 데이터 다운로드('punkt : 문장 분리 모델') 
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\okss2\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\okss2\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
print('단어 토큰화1 :',word_tokenize("Don't be fooled by the dark sounding name, Mr. Jone's Orphanage is as cheery as cheery goes for a pastry shop."))
# Out:
# 단어 토큰화1 : ['Do', "n't", 'be', 'fooled', 'by', 'the', 'dark', 'sounding', 'name', ',', 'Mr.', 'Jone', "'s", 'Orphanage', 'is', 'as', 'cheery', 'as', 'cheery', 'goes', 'for', 'a', 'pastry', 'shop', '.']

# %%
print('단어 토큰화2 :',WordPunctTokenizer().tokenize("Don't be fooled by the dark sounding name, Mr. Jone's Orphanage is as cheery as cheery goes for a pastry shop."))
# Out:
# 단어 토큰화2 : ['Don', "'", 't', 'be', 'fooled', 'by', 'the', 'dark', 'sounding', 'name', ',', 'Mr', '.', 'Jone', "'", 's', 'Orphanage', 'is', 'as', 'cheery', 'as', 'cheery', 'goes', 'for', 'a', 'pastry', 'shop', '.']

# %%
print('단어 토큰화3 :',text_to_word_sequence("Don't be fooled by the dark sounding name, Mr. Jone's Orphanage is as cheery as cheery goes for a pastry shop."))
# Out:
# 단어 토큰화3 : ["don't", 'be', 'fooled', 'by', 'the', 'dark', 'sounding', 'name', 'mr', "jone's", 'orphanage', 'is', 'as', 'cheery', 'as', 'cheery', 'goes', 'for', 'a', 'pastry', 'shop']

# %%
from nltk.tokenize import TreebankWordTokenizer

tokenizer = TreebankWordTokenizer()

text = "Starting a home-based restaurant may be an ideal. it doesn't have a food chain or restaurant of their own."
print('트리뱅크 워드토크나이저 :',tokenizer.tokenize(text))
# Out:
# 트리뱅크 워드토크나이저 : ['Starting', 'a', 'home-based', 'restaurant', 'may', 'be', 'an', 'ideal.', 'it', 'does', "n't", 'have', 'a', 'food', 'chain', 'or', 'restaurant', 'of', 'their', 'own', '.']

# %%
# 문장토큰화
from nltk.tokenize import sent_tokenize

text = "His barber kept his word. But keeping such a huge secret to himself was driving him crazy. Finally, the barber went up a mountain and almost to the edge of a cliff. He dug a hole in the midst of some reeds. He looked about, to make sure no one was near."
print('문장 토큰화1 :',sent_tokenize(text))
# Out:
# 문장 토큰화1 : ['His barber kept his word.', 'But keeping such a huge secret to himself was driving him crazy.', 'Finally, the barber went up a mountain and almost to the edge of a cliff.', 'He dug a hole in the midst of some reeds.', 'He looked about, to make sure no one was near.']

# %%
text = "I am actively looking for Ph.D. students. and you are a Ph.D student."
print('문장 토큰화2 :',sent_tokenize(text))
# Out:
# 문장 토큰화2 : ['I am actively looking for Ph.D. students.', 'and you are a Ph.D student.']

# %%
# 한국어 문장 토큰화

import kss

text = '딥 러닝 자연어 처리가 재미있기는 합니다. 그런데 문제는 영어보다 한국어로 할 때 너무 어렵습니다. 이제 해보면 알걸요?'
print('한국어 문장 토큰화 :',kss.split_sentences(text))
# Out:
# [Kss]: Because there's no supported C++ morpheme analyzer, Kss will take pecab as a backend. :D
# For your information, Kss also supports mecab backend.
# We recommend you to install mecab or konlpy.tag.Mecab for faster execution of Kss.
# Please refer to following web sites for details:
# - mecab: https://cleancode-ws.tistory.com/97
# - konlpy.tag.Mecab: https://uwgdqo.tistory.com/363
# 한국어 문장 토큰화 : ['딥 러닝 자연어 처리가 재미있기는 합니다.', '그런데 문제는 영어보다 한국어로 할 때 너무 어렵습니다.', '이제 해보면 알걸요?']
# c:\AI\envs\ai\lib\site-packages\pecab\_tokenizer.py:265: RuntimeWarning: overflow encountered in scalar add
#   from_pos_data.costs[idx]

# %%
# NLTK와 KoNLPy를 이용한 영어, 한국어 토큰화 실습
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag

# %%
import nltk
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\okss2\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
text = "I am actively looking for Ph.D. students. and you are a Ph.D. student."
tokenized_sentence = word_tokenize(text)

print('단어 토큰화 :',tokenized_sentence)
print('품사 태깅 :',pos_tag(tokenized_sentence))
# Out:
# 단어 토큰화 : ['I', 'am', 'actively', 'looking', 'for', 'Ph.D.', 'students', '.', 'and', 'you', 'are', 'a', 'Ph.D.', 'student', '.']
# 품사 태깅 : [('I', 'PRP'), ('am', 'VBP'), ('actively', 'RB'), ('looking', 'VBG'), ('for', 'IN'), ('Ph.D.', 'NNP'), ('students', 'NNS'), ('.', '.'), ('and', 'CC'), ('you', 'PRP'), ('are', 'VBP'), ('a', 'DT'), ('Ph.D.', 'NNP'), ('student', 'NN'), ('.', '.')]

# %%
from konlpy.tag import Okt
from konlpy.tag import Kkma

# %%
okt = Okt()
kkma = Kkma()

# %%
print('OKT 형태소 분석 :',okt.morphs("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
print('OKT 품사 태깅 :',okt.pos("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
print('OKT 명사 추출 :',okt.nouns("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
# Out:
# OKT 형태소 분석 : ['열심히', '코딩', '한', '당신', ',', '연휴', '에는', '여행', '을', '가봐요']
# OKT 품사 태깅 : [('열심히', 'Adverb'), ('코딩', 'Noun'), ('한', 'Josa'), ('당신', 'Noun'), (',', 'Punctuation'), ('연휴', 'Noun'), ('에는', 'Josa'), ('여행', 'Noun'), ('을', 'Josa'), ('가봐요', 'Verb')]
# OKT 명사 추출 : ['코딩', '당신', '연휴', '여행']

# %%
print('꼬꼬마 형태소 분석 :',kkma.morphs("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
print('꼬꼬마 품사 태깅 :',kkma.pos("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
print('꼬꼬마 명사 추출 :',kkma.nouns("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
# Out:
# 꼬꼬마 형태소 분석 : ['열심히', '코딩', '하', 'ㄴ', '당신', ',', '연휴', '에', '는', '여행', '을', '가보', '아요']
# 꼬꼬마 품사 태깅 : [('열심히', 'MAG'), ('코딩', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('당신', 'NP'), (',', 'SP'), ('연휴', 'NNG'), ('에', 'JKM'), ('는', 'JX'), ('여행', 'NNG'), ('을', 'JKO'), ('가보', 'VV'), ('아요', 'EFN')]
# 꼬꼬마 명사 추출 : ['코딩', '당신', '연휴', '여행']
