# %%
# Linked List 노드클래스 정의하기
class Node:
  def __init__(self, data):
    self.data = data # data 는 값을 가리키는 변수(속성, attribute)
    self.next = None # next는 다음 노드를 가리키는 변수

head = Node(1)  # 첫째 노드 .(head)
head.next = Node(2) # head의 next가 둘째 노드를 가리키도록 한다.
head.next.next = Node(3)  # head 의 next 의 next 가 셋째 노드를 가리키도록 한다.

# %%
# Linked List 연결리스트 구현 절차 - 연결리스트의 값을 순서대로 출력하기
node = head
while node: # node is not None 과 같은 코드
    print(node.data, end = " ")
    node = node.next
# Out:
# 1 2 3

# %%
# Linked List 연결리스트 의 끝에 새 노드를 추가

class Node:
  def __init__(self, data):
    self.data = data
    self.next = None

head  = Node(1)
head.next = Node(2)
head.next.next =  Node(3)

'''
node = head
while node:
  if node.next is None:
    node.next = Node(4)
    break
  node = node.next
'''
# 기존 while 문 코드 줄이기 . 마지막 노드까지 이동하는 방법을 수정. (가독성)
node = head
while node.next: # 현재 노드의 next가 None 이 아닐 동안 실행
  node = node.next
node.next = Node(4)

# 기존 노드에 0번째 노드 추가
node = Node(0)
node.next = head
head = node
