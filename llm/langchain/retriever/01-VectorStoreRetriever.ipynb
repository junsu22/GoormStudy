# %% [markdown]
# # 벡터스토어 기반 검색기(VectorStore-backed Retriever)
#
# **VectorStore 지원 검색기** 는 vector store를 사용하여 문서를 검색하는 retriever입니다.
#
# Vector store에 구현된 **유사도 검색(similarity search)** 이나 **MMR** 과 같은 검색 메서드를 사용하여 vector store 내의 텍스트를 쿼리합니다.

# %% [markdown]
# 아래의 코드를 실행하여 VectorStore 를 생성합니다.

# %%
# API 키를 환경변수로 관리하기 위한 설정 파일
from dotenv import load_dotenv

# API 키 정보 로드
load_dotenv()
# Out:
# python-dotenv could not parse statement starting at line 23
# True

# %%
# !pip install langchain-teddynote
# Out:
# Collecting langchain-teddynote
#   Downloading langchain_teddynote-0.5.4-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: anthropic>=0.64.0 in c:\users\pc\miniconda3\lib\site-packages (from langchain-teddynote) (0.84.0)
# Collecting deepl>=1.22.0 (from langchain-teddynote)
#   Downloading deepl-1.30.0-py3-none-any.whl.metadata (42 kB)
# Collecting feedparser>=6.0.11 (from langchain-teddynote)
#   Downloading feedparser-6.0.12-py3-none-any.whl.metadata (2.7 kB)
# Collecting kiwipiepy>=0.21.0 (from langchain-teddynote)
#   Downloading kiwipiepy-0.23.1-cp39-abi3-win_amd64.whl.metadata (1.3 kB)
# Collecting konlpy>=0.6.0 (from langchain-teddynote)
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting langchain-openai>=0.3.30 (from langchain-teddynote)
#   Downloading langchain_openai-1.1.12-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: langchain>=0.3.27 in c:\users\pc\miniconda3\lib\site-packages (from langchain-teddynote) (1.2.10)
# Requirement already satisfied: langgraph>=0.6.5 in c:\users\pc\miniconda3\lib\site-packages (from langchain-teddynote) (1.0.10)
# Collecting olefile>=0.47 (from langchain-teddynote)
#   Downloading olefile-0.47-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting openai>=1.99.9 (from langchain-teddynote)
#   Downloading openai-2.31.0-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: pandas>=2.3.1 in c:\users\pc\miniconda3\lib\site-packages (from langchain-teddynote) (2.3.3)
# Collecting pdf2image>=1.17.0 (from langchain-teddynote)
#   Downloading pdf2image-1.17.0-py3-none-any.whl.metadata (6.2 kB)
# Collecting pinecone-client>=6.0.0 (from langchain-teddynote)
#   Downloading pinecone_client-6.0.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting pinecone-text>=0.11.0 (from langchain-teddynote)
#   Downloading pinecone_text-0.11.0-py3-none-any.whl.metadata (10 kB)
# Collecting python-dotenv>=1.1.1 (from langchain-teddynote)
#   Downloading python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Collecting rank-bm25>=0.2.2 (from langchain-teddynote)
#   Downloading rank_bm25-0.2.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting tavily-python>=0.7.10 (from langchain-teddynote)
#   Downloading tavily_python-0.7.23-py3-none-any.whl.metadata (10 kB)
# Collecting twine>=6.1.0 (from langchain-teddynote)
#   Downloading twine-6.2.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\pc\miniconda3\lib\site-packages (from anthropic>=0.64.0->langchain-teddynote) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\pc\miniconda3\lib\site-packages (from anthropic>=0.64.0->langchain-teddynote) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in c:\users\pc\miniconda3\lib\site-packages (from anthropic>=0.64.0->langchain-teddynote) (0.17.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\pc\miniconda3\lib\site-packages (from anthropic>=0.64.0->langchain-teddynote) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\pc\miniconda3\lib\site-packages (from anthropic>=0.64.0->langchain-teddynote) (0.13.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\pc\miniconda3\lib\site-packages (from anthropic>=0.64.0->langchain-teddynote) (2.12.4)
# Requirement already satisfied: sniffio in c:\users\pc\miniconda3\lib\site-packages (from anthropic>=0.64.0->langchain-teddynote) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in c:\users\pc\miniconda3\lib\site-packages (from anthropic>=0.64.0->langchain-teddynote) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\users\pc\miniconda3\lib\site-packages (from anyio<5,>=3.5.0->anthropic>=0.64.0->langchain-teddynote) (3.11)
# Requirement already satisfied: certifi in c:\users\pc\miniconda3\lib\site-packages (from httpx<1,>=0.25.0->anthropic>=0.64.0->langchain-teddynote) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\pc\miniconda3\lib\site-packages (from httpx<1,>=0.25.0->anthropic>=0.64.0->langchain-teddynote) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\pc\miniconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic>=0.64.0->langchain-teddynote) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\pc\miniconda3\lib\site-packages (from pydantic<3,>=1.9.0->anthropic>=0.64.0->langchain-teddynote) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\pc\miniconda3\lib\site-packages (from pydantic<3,>=1.9.0->anthropic>=0.64.0->langchain-teddynote) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\pc\miniconda3\lib\site-packages (from pydantic<3,>=1.9.0->anthropic>=0.64.0->langchain-teddynote) (0.4.2)
# Requirement already satisfied: requests>=2.32.5 in c:\users\pc\miniconda3\lib\site-packages (from deepl>=1.22.0->langchain-teddynote) (2.32.5)
# Collecting sgmllib3k (from feedparser>=6.0.11->langchain-teddynote)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting kiwipiepy_model<0.24,>=0.23 (from kiwipiepy>=0.21.0->langchain-teddynote)
#   Downloading kiwipiepy_model-0.23.0.tar.gz (88.0 MB)
#      ---------------------------------------- 0.0/88.0 MB ? eta -:--:--
#      - -------------------------------------- 4.2/88.0 MB 27.8 MB/s eta 0:00:04
#      --- ------------------------------------ 8.4/88.0 MB 22.0 MB/s eta 0:00:04
#      ------- ------------------------------- 16.8/88.0 MB 32.0 MB/s eta 0:00:03
#      ------- ------------------------------- 17.6/88.0 MB 22.3 MB/s eta 0:00:04
#      ------------ -------------------------- 29.1/88.0 MB 28.4 MB/s eta 0:00:03
#      ------------------ -------------------- 40.9/88.0 MB 33.2 MB/s eta 0:00:02
#      ---------------------- ---------------- 51.1/88.0 MB 35.2 MB/s eta 0:00:02
#      -------------------------- ------------ 59.0/88.0 MB 35.5 MB/s eta 0:00:01
#      --------------------------- ----------- 61.1/88.0 MB 33.7 MB/s eta 0:00:01
#      ----------------------------- --------- 66.6/88.0 MB 32.0 MB/s eta 0:00:01
#      --------------------------------- ----- 74.7/88.0 MB 32.6 MB/s eta 0:00:01
#      ------------------------------------- - 83.6/88.0 MB 33.5 MB/s eta 0:00:01
#      ---------------------------------------- 88.0/88.0 MB 32.6 MB/s  0:00:02
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy in c:\users\pc\miniconda3\lib\site-packages (from kiwipiepy>=0.21.0->langchain-teddynote) (2.3.5)
# Requirement already satisfied: tqdm in c:\users\pc\miniconda3\lib\site-packages (from kiwipiepy>=0.21.0->langchain-teddynote) (4.67.1)
# Collecting JPype1>=0.7.0 (from konlpy>=0.6.0->langchain-teddynote)
#   Downloading jpype1-1.7.0-cp313-cp313-win_amd64.whl.metadata (4.6 kB)
# Collecting lxml>=4.1.0 (from konlpy>=0.6.0->langchain-teddynote)
#   Downloading lxml-6.0.3-cp313-cp313-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: packaging in c:\users\pc\miniconda3\lib\site-packages (from JPype1>=0.7.0->konlpy>=0.6.0->langchain-teddynote) (25.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in c:\users\pc\miniconda3\lib\site-packages (from langchain>=0.3.27->langchain-teddynote) (1.2.17)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\pc\miniconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain>=0.3.27->langchain-teddynote) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\pc\miniconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain>=0.3.27->langchain-teddynote) (0.7.14)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\pc\miniconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain>=0.3.27->langchain-teddynote) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\pc\miniconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain>=0.3.27->langchain-teddynote) (9.1.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\pc\miniconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain>=0.3.27->langchain-teddynote) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\pc\miniconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain>=0.3.27->langchain-teddynote) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\users\pc\miniconda3\lib\site-packages (from langgraph>=0.6.5->langchain-teddynote) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.8 in c:\users\pc\miniconda3\lib\site-packages (from langgraph>=0.6.5->langchain-teddynote) (1.0.8)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\pc\miniconda3\lib\site-packages (from langgraph>=0.6.5->langchain-teddynote) (0.3.9)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\pc\miniconda3\lib\site-packages (from langgraph>=0.6.5->langchain-teddynote) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\pc\miniconda3\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph>=0.6.5->langchain-teddynote) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in c:\users\pc\miniconda3\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph>=0.6.5->langchain-teddynote) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\pc\miniconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain>=0.3.27->langchain-teddynote) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\pc\miniconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain>=0.3.27->langchain-teddynote) (0.24.0)
# Collecting langchain-core<2.0.0,>=1.2.10 (from langchain>=0.3.27->langchain-teddynote)
#   Downloading langchain_core-1.2.28-py3-none-any.whl.metadata (4.4 kB)
# Collecting tiktoken<1.0.0,>=0.7.0 (from langchain-openai>=0.3.30->langchain-teddynote)
#   Downloading tiktoken-0.12.0-cp313-cp313-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\pc\miniconda3\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai>=0.3.30->langchain-teddynote) (2026.2.28)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pc\miniconda3\lib\site-packages (from pandas>=2.3.1->langchain-teddynote) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pc\miniconda3\lib\site-packages (from pandas>=2.3.1->langchain-teddynote) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\pc\miniconda3\lib\site-packages (from pandas>=2.3.1->langchain-teddynote) (2025.3)
# Requirement already satisfied: pillow in c:\users\pc\miniconda3\lib\site-packages (from pdf2image>=1.17.0->langchain-teddynote) (11.1.0)
# Collecting pinecone-plugin-interface<0.0.8,>=0.0.7 (from pinecone-client>=6.0.0->langchain-teddynote)
#   Downloading pinecone_plugin_interface-0.0.7-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: urllib3>=1.26.5 in c:\users\pc\miniconda3\lib\site-packages (from pinecone-client>=6.0.0->langchain-teddynote) (2.6.1)
# Collecting mmh3<5.0.0,>=4.1.0 (from pinecone-text>=0.11.0->langchain-teddynote)
#   Downloading mmh3-4.1.0.tar.gz (26 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting nltk<4.0.0,>=3.9.1 (from pinecone-text>=0.11.0->langchain-teddynote)
#   Downloading nltk-3.9.4-py3-none-any.whl.metadata (3.2 kB)
# Collecting types-requests<3.0.0,>=2.25.0 (from pinecone-text>=0.11.0->langchain-teddynote)
#   Downloading types_requests-2.33.0.20260408-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: click in c:\users\pc\miniconda3\lib\site-packages (from nltk<4.0.0,>=3.9.1->pinecone-text>=0.11.0->langchain-teddynote) (8.2.1)
# Requirement already satisfied: joblib in c:\users\pc\miniconda3\lib\site-packages (from nltk<4.0.0,>=3.9.1->pinecone-text>=0.11.0->langchain-teddynote) (1.5.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\pc\miniconda3\lib\site-packages (from requests>=2.32.5->deepl>=1.22.0->langchain-teddynote) (3.4.4)
# Requirement already satisfied: six>=1.5 in c:\users\pc\miniconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.3.1->langchain-teddynote) (1.17.0)
# Requirement already satisfied: colorama in c:\users\pc\miniconda3\lib\site-packages (from tqdm->kiwipiepy>=0.21.0->langchain-teddynote) (0.4.6)
# Collecting readme-renderer>=35.0 (from twine>=6.1.0->langchain-teddynote)
#   Downloading readme_renderer-44.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: keyring>=21.2.0 in c:\users\pc\miniconda3\lib\site-packages (from twine>=6.1.0->langchain-teddynote) (25.7.0)
# Collecting rfc3986>=1.4.0 (from twine>=6.1.0->langchain-teddynote)
#   Downloading rfc3986-2.0.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: rich>=12.0.0 in c:\users\pc\miniconda3\lib\site-packages (from twine>=6.1.0->langchain-teddynote) (14.2.0)
# Collecting id (from twine>=6.1.0->langchain-teddynote)
#   Downloading id-1.6.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: pywin32-ctypes>=0.2.0 in c:\users\pc\miniconda3\lib\site-packages (from keyring>=21.2.0->twine>=6.1.0->langchain-teddynote) (0.2.2)
# Requirement already satisfied: jaraco.classes in c:\users\pc\miniconda3\lib\site-packages (from keyring>=21.2.0->twine>=6.1.0->langchain-teddynote) (3.4.0)
# Requirement already satisfied: jaraco.functools in c:\users\pc\miniconda3\lib\site-packages (from keyring>=21.2.0->twine>=6.1.0->langchain-teddynote) (4.1.0)
# Requirement already satisfied: jaraco.context in c:\users\pc\miniconda3\lib\site-packages (from keyring>=21.2.0->twine>=6.1.0->langchain-teddynote) (0.0.0)
# Collecting nh3>=0.2.14 (from readme-renderer>=35.0->twine>=6.1.0->langchain-teddynote)
#   Downloading nh3-0.3.4-cp38-abi3-win_amd64.whl.metadata (2.0 kB)
# Collecting docutils>=0.21.2 (from readme-renderer>=35.0->twine>=6.1.0->langchain-teddynote)
#   Downloading docutils-0.22.4-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: Pygments>=2.5.1 in c:\users\pc\miniconda3\lib\site-packages (from readme-renderer>=35.0->twine>=6.1.0->langchain-teddynote) (2.19.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\pc\miniconda3\lib\site-packages (from rich>=12.0.0->twine>=6.1.0->langchain-teddynote) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\pc\miniconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->twine>=6.1.0->langchain-teddynote) (0.1.2)
# Requirement already satisfied: more_itertools in c:\users\pc\miniconda3\lib\site-packages (from jaraco.classes->keyring>=21.2.0->twine>=6.1.0->langchain-teddynote) (10.8.0)
# Downloading langchain_teddynote-0.5.4-py3-none-any.whl (63 kB)
# Downloading deepl-1.30.0-py3-none-any.whl (49 kB)
# Downloading feedparser-6.0.12-py3-none-any.whl (81 kB)
# Downloading kiwipiepy-0.23.1-cp39-abi3-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------------------------- 2.7/2.7 MB 43.6 MB/s  0:00:00
# Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#    ---------------------------------------- 0.0/19.4 MB ? eta -:--:--
#    ------------------ --------------------- 9.2/19.4 MB 44.3 MB/s eta 0:00:01
#    ---------------------------------------  19.4/19.4 MB 48.3 MB/s eta 0:00:01
#    ---------------------------------------- 19.4/19.4 MB 45.1 MB/s  0:00:00
# Downloading jpype1-1.7.0-cp313-cp313-win_amd64.whl (356 kB)
# Downloading langchain_openai-1.1.12-py3-none-any.whl (88 kB)
# Downloading langchain_core-1.2.28-py3-none-any.whl (508 kB)
# Downloading openai-2.31.0-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 31.0 MB/s  0:00:00
# Downloading tiktoken-0.12.0-cp313-cp313-win_amd64.whl (879 kB)
#    ---------------------------------------- 0.0/879.1 kB ? eta -:--:--
#    ---------------------------------------- 879.1/879.1 kB 25.4 MB/s  0:00:00
# Downloading lxml-6.0.3-cp313-cp313-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 4.0/4.0 MB 33.1 MB/s  0:00:00
# Downloading olefile-0.47-py2.py3-none-any.whl (114 kB)
# Downloading pdf2image-1.17.0-py3-none-any.whl (11 kB)
# Downloading pinecone_client-6.0.0-py3-none-any.whl (6.7 kB)
# Downloading pinecone_plugin_interface-0.0.7-py3-none-any.whl (6.2 kB)
# Downloading pinecone_text-0.11.0-py3-none-any.whl (22 kB)
# Downloading nltk-3.9.4-py3-none-any.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 1.6/1.6 MB 26.6 MB/s  0:00:00
# Downloading python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Downloading types_requests-2.33.0.20260408-py3-none-any.whl (20 kB)
# Downloading rank_bm25-0.2.2-py3-none-any.whl (8.6 kB)
# Downloading tavily_python-0.7.23-py3-none-any.whl (19 kB)
# Downloading twine-6.2.0-py3-none-any.whl (42 kB)
# Downloading readme_renderer-44.0-py3-none-any.whl (13 kB)
# Downloading docutils-0.22.4-py3-none-any.whl (633 kB)
#    ---------------------------------------- 0.0/633.2 kB ? eta -:--:--
#    ---------------------------------------- 633.2/633.2 kB 18.6 MB/s  0:00:00
# Downloading nh3-0.3.4-cp38-abi3-win_amd64.whl (624 kB)
#    ---------------------------------------- 0.0/624.2 kB ? eta -:--:--
#    ---------------------------------------- 624.2/624.2 kB 18.2 MB/s  0:00:00
# Downloading rfc3986-2.0.0-py2.py3-none-any.whl (31 kB)
# Downloading id-1.6.1-py3-none-any.whl (14 kB)
# Building wheels for collected packages: kiwipiepy_model, mmh3, sgmllib3k
#   Building wheel for kiwipiepy_model (pyproject.toml): started
#   Building wheel for kiwipiepy_model (pyproject.toml): finished with status 'done'
#   Created wheel for kiwipiepy_model: filename=kiwipiepy_model-0.23.0-py3-none-any.whl size=88067888 sha256=a80a1261fb30196a1a504f6938f76ea4e586c8999ac5c9d878982d1d6ee6066a
#   Stored in directory: c:\users\pc\appdata\local\pip\cache\wheels\ec\af\43\b8cbacbd3ffba62b7097221eca55b7a4bfd7bea5d2eaadcbeb
#   Building wheel for mmh3 (pyproject.toml): started
#   Building wheel for mmh3 (pyproject.toml): finished with status 'done'
#   Created wheel for mmh3: filename=mmh3-4.1.0-cp313-cp313-win_amd64.whl size=31523 sha256=bdd6946f2c8a1d8a60048727f3cfbe6ec12c8f98bacf7156e0dab8e32790392f
#   Stored in directory: c:\users\pc\appdata\local\pip\cache\wheels\57\68\ca\1b7f541c188850a92dc3011ea464115ab2171bff64606c54f5
#   Building wheel for sgmllib3k (pyproject.toml): started
#   Building wheel for sgmllib3k (pyproject.toml): finished with status 'done'
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6104 sha256=97f067d34e432e6f3a6c259667b462131597ff45c8d4ed5015eaf618611fea50
#   Stored in directory: c:\users\pc\appdata\local\pip\cache\wheels\3d\4d\ef\37cdccc18d6fd7e0dd7817dcdf9146d4d6789c32a227a28134
# Successfully built kiwipiepy_model mmh3 sgmllib3k
# Installing collected packages: sgmllib3k, mmh3, kiwipiepy_model, types-requests, rfc3986, rank-bm25, python-dotenv, pinecone-plugin-interface, pdf2image, olefile, nh3, lxml, JPype1, id, feedparser, docutils, tiktoken, readme-renderer, pinecone-client, nltk, konlpy, kiwipiepy, deepl, twine, tavily-python, pinecone-text, openai, langchain-core, langchain-openai, langchain-teddynote
#
#   Attempting uninstall: mmh3
#
#     Found existing installation: mmh3 5.2.1
#
#     Uninstalling mmh3-5.2.1:
#
#    - --------------------------------------  1/30 [mmh3]
#    - --------------------------------------  1/30 [mmh3]
#    - --------------------------------------  1/30 [mmh3]
#    - --------------------------------------  1/30 [mmh3]
#    - --------------------------------------  1/30 [mmh3]
#    - --------------------------------------  1/30 [mmh3]
#    - --------------------------------------  1/30 [mmh3]
#    - --------------------------------------  1/30 [mmh3]
#    - --------------------------------------  1/30 [mmh3]
#    - --------------------------------------  1/30 [mmh3]
#    - --------------------------------------  1/30 [mmh3]
#       Successfully uninstalled mmh3-5.2.1
#    - --------------------------------------  1/30 [mmh3]
#    -- -------------------------------------  2/30 [kiwipiepy_model]
#    -- -------------------------------------  2/30 [kiwipiepy_model]
#    -- -------------------------------------  2/30 [kiwipiepy_model]
#    ---- -----------------------------------  3/30 [types-requests]
#   Attempting uninstall: python-dotenv
#    ---- -----------------------------------  3/30 [types-requests]
#     Found existing installation: python-dotenv 1.1.0
#    ---- -----------------------------------  3/30 [types-requests]
#     Uninstalling python-dotenv-1.1.0:
#    ---- -----------------------------------  3/30 [types-requests]
#       Successfully uninstalled python-dotenv-1.1.0
#    ---- -----------------------------------  3/30 [types-requests]
#    -------- -------------------------------  6/30 [python-dotenv]
#    -------------- ------------------------- 11/30 [lxml]
#    -------------- ------------------------- 11/30 [lxml]
#    -------------- ------------------------- 11/30 [lxml]
#    ---------------- ----------------------- 12/30 [JPype1]
#    ------------------ --------------------- 14/30 [feedparser]
#    -------------------- ------------------- 15/30 [docutils]
#    -------------------- ------------------- 15/30 [docutils]
#    -------------------- ------------------- 15/30 [docutils]
#    -------------------- ------------------- 15/30 [docutils]
#    -------------------- ------------------- 15/30 [docutils]
#    ------------------------- -------------- 19/30 [nltk]
#    ------------------------- -------------- 19/30 [nltk]
#    ------------------------- -------------- 19/30 [nltk]
#    ------------------------- -------------- 19/30 [nltk]
#    ------------------------- -------------- 19/30 [nltk]
#    ------------------------- -------------- 19/30 [nltk]
#    ------------------------- -------------- 19/30 [nltk]
#    ------------------------- -------------- 19/30 [nltk]
#    ------------------------- -------------- 19/30 [nltk]
#    ------------------------- -------------- 19/30 [nltk]
#    ------------------------- -------------- 19/30 [nltk]
#    ------------------------- -------------- 19/30 [nltk]
#    -------------------------- ------------- 20/30 [konlpy]
#    ---------------------------- ----------- 21/30 [kiwipiepy]
#    ----------------------------- ---------- 22/30 [deepl]
#    --------------------------------- ------ 25/30 [pinecone-text]
#    ---------------------------------- ----- 26/30 [openai]
#    ---------------------------------- ----- 26/30 [openai]
#    ---------------------------------- ----- 26/30 [openai]
#    ---------------------------------- ----- 26/30 [openai]
#    ---------------------------------- ----- 26/30 [openai]
#    ---------------------------------- ----- 26/30 [openai]
#    ---------------------------------- ----- 26/30 [openai]
#    ---------------------------------- ----- 26/30 [openai]
#    ---------------------------------- ----- 26/30 [openai]
#    ---------------------------------- ----- 26/30 [openai]
#    ---------------------------------- ----- 26/30 [openai]
#    ---------------------------------- ----- 26/30 [openai]
#    ---------------------------------- ----- 26/30 [openai]
#    ---------------------------------- ----- 26/30 [openai]
#    ---------------------------------- ----- 26/30 [openai]
#    ---------------------------------- ----- 26/30 [openai]
#    ---------------------------------- ----- 26/30 [openai]
#    ---------------------------------- ----- 26/30 [openai]
#    ---------------------------------- ----- 26/30 [openai]
#    ---------------------------------- ----- 26/30 [openai]
#    ---------------------------------- ----- 26/30 [openai]
#    ---------------------------------- ----- 26/30 [openai]
#    ---------------------------------- ----- 26/30 [openai]
#   Attempting uninstall: langchain-core
#    ---------------------------------- ----- 26/30 [openai]
#     Found existing installation: langchain-core 1.2.17
#    ---------------------------------- ----- 26/30 [openai]
#     Uninstalling langchain-core-1.2.17:
#    ---------------------------------- ----- 26/30 [openai]
#       Successfully uninstalled langchain-core-1.2.17
#    ---------------------------------- ----- 26/30 [openai]
#    ------------------------------------ --- 27/30 [langchain-core]
#    ------------------------------------ --- 27/30 [langchain-core]
#    ------------------------------------ --- 27/30 [langchain-core]
#    ------------------------------------ --- 27/30 [langchain-core]
#    ------------------------------------ --- 27/30 [langchain-core]
#    ------------------------------------ --- 27/30 [langchain-core]
#    ------------------------------------- -- 28/30 [langchain-openai]
#    -------------------------------------- - 29/30 [langchain-teddynote]
#    ---------------------------------------- 30/30 [langchain-teddynote]
#
# Successfully installed JPype1-1.7.0 deepl-1.30.0 docutils-0.22.4 feedparser-6.0.12 id-1.6.1 kiwipiepy-0.23.1 kiwipiepy_model-0.23.0 konlpy-0.6.0 langchain-core-1.2.28 langchain-openai-1.1.12 langchain-teddynote-0.5.4 lxml-6.0.3 mmh3-4.1.0 nh3-0.3.4 nltk-3.9.4 olefile-0.47 openai-2.31.0 pdf2image-1.17.0 pinecone-client-6.0.0 pinecone-plugin-interface-0.0.7 pinecone-text-0.11.0 python-dotenv-1.2.2 rank-bm25-0.2.2 readme-renderer-44.0 rfc3986-2.0.0 sgmllib3k-1.0.0 tavily-python-0.7.23 tiktoken-0.12.0 twine-6.2.0 types-requests-2.33.0.20260408

# %%
# LangSmith 추적을 설정합니다. https://smith.langchain.com
# !pip install langchain-teddynote
from langchain_teddynote import logging

# 프로젝트 이름을 입력합니다.
logging.langsmith("CH10-Retriever")
# Out:
# LangSmith 추적을 시작합니다.
# [프로젝트명]
# CH10-Retriever

# %%
# !pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Using cached faiss_cpu-1.13.2-cp313-cp313-win_amd64.whl.metadata (7.6 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in c:\users\pc\miniconda3\lib\site-packages (from faiss-cpu) (2.3.5)
# Requirement already satisfied: packaging in c:\users\pc\miniconda3\lib\site-packages (from faiss-cpu) (25.0)
# Downloading faiss_cpu-1.13.2-cp313-cp313-win_amd64.whl (18.9 MB)
#    ---------------------------------------- 0.0/18.9 MB ? eta -:--:--
#    --------- ------------------------------ 4.5/18.9 MB 24.6 MB/s eta 0:00:01
#    ------------------------------- -------- 14.7/18.9 MB 37.3 MB/s eta 0:00:01
#    ---------------------------------------  18.9/18.9 MB 31.5 MB/s eta 0:00:01
#    ---------------------------------------- 18.9/18.9 MB 29.2 MB/s  0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.13.2

# %%
from langchain_community.vectorstores import FAISS
from langchain_openai import OpenAIEmbeddings
from langchain_text_splitters import CharacterTextSplitter
from langchain_community.document_loaders import TextLoader

# TextLoader를 사용하여 파일을 로드합니다.
loader = TextLoader("./data/appendix-keywords.txt")

# 문서를 로드합니다.
documents = loader.load()

# 문자 기반으로 텍스트를 분할하는 CharacterTextSplitter를 생성합니다. 청크 크기는 300이고 청크 간 중복은 없습니다.
text_splitter = CharacterTextSplitter(chunk_size=300, chunk_overlap=0)

# 로드된 문서를 분할합니다.
split_docs = text_splitter.split_documents(documents)

# OpenAI 임베딩을 생성합니다.
embeddings = OpenAIEmbeddings()

# 분할된 텍스트와 임베딩을 사용하여 FAISS 벡터 데이터베이스를 생성합니다.
db = FAISS.from_documents(split_docs, embeddings)

# %% [markdown]
# ### VectorStore에서 VectorStoreRetriever 초기화(as_retriever)
#
# `as_retriever` 메서드는 VectorStore 객체를 기반으로 VectorStoreRetriever를 초기화하고 반환합니다. 이 메서드를 통해 다양한 검색 옵션을 설정하여 사용자의 요구에 맞는 문서 검색을 수행할 수 있습니다.
#
# **매개변수(parameters)**
#
# - `**kwargs`: 검색 함수에 전달할 키워드 인자
#   - `search_type`: 검색 유형 ("similarity", "mmr", "similarity_score_threshold")
#   - `search_kwargs`: 추가 검색 옵션
#     - `k`: 반환할 문서 수 (기본값: 4)
#     - `score_threshold`: similarity_score_threshold 검색의 최소 유사도 임계값
#     - `fetch_k`: MMR 알고리즘에 전달할 문서 수 (기본값: 20)
#     - `lambda_mult`: MMR 결과의 다양성 조절 (0-1 사이, 기본값: 0.5)
#     - `filter`: 문서 메타데이터 기반 필터링
#
# **반환값(return)**
#
# - `VectorStoreRetriever`: 초기화된 VectorStoreRetriever 객체
#
# **참고**
#
# - 다양한 검색 전략 구현 가능 (유사도, MMR, 임계값 기반)
# - MMR (Maximal Marginal Relevance) 알고리즘으로 검색 결과의 다양성 조절 가능
# - 메타데이터 필터링으로 특정 조건의 문서만 검색 가능
# - `tags` 매개변수를 통해 검색기에 태그 추가 가능
#
# **주의사항**
#
# - `search_type`과 `search_kwargs`의 적절한 조합 필요
# - MMR 사용 시 `fetch_k`와 `k` 값의 균형 조절 필요
# - `score_threshold` 설정 시 너무 높은 값은 검색 결과가 없을 수 있음
# - 필터 사용 시 데이터셋의 메타데이터 구조 정확히 파악 필요
# - `lambda_mult` 값이 0에 가까울수록 다양성이 높아지고, 1에 가까울수록 유사성이 높아짐

# %%
# 데이터베이스를 검색기로 사용하기 위해 retriever 변수에 할당
retriever = db.as_retriever()

# %% [markdown]
# ### Retriever의 invoke()
#
# `invoke` 메서드는 Retriever의 주요 진입점으로, 관련 문서를 검색하는 데 사용됩니다. 이 메서드는 동기적으로 Retriever를 호출하여 주어진 쿼리에 대한 관련 문서를 반환합니다.
#
# **매개변수(parameters)**
#
# - `input`: 검색 쿼리 문자열
# - `config`: Retriever 구성 (Optional[RunnableConfig])
# - `**kwargs`: Retriever에 전달할 추가 인자
#
# **반환값(return)**
#
# - `List[Document]`: 관련 문서 목록

# %%
# 관련 문서를 검색
docs = retriever.invoke("임베딩(Embedding)은 무엇인가요?")

for doc in docs:
    print(doc.page_content)
    print("=========================================================")
# Out:
# 정의: 임베딩은 단어나 문장 같은 텍스트 데이터를 저차원의 연속적인 벡터로 변환하는 과정입니다. 이를 통해 컴퓨터가 텍스트를 이해하고 처리할 수 있게 합니다.
# 예시: "사과"라는 단어를 [0.65, -0.23, 0.17]과 같은 벡터로 표현합니다.
# 연관키워드: 자연어 처리, 벡터화, 딥러닝
#
# Token
# =========================================================
# 정의: Word2Vec은 단어를 벡터 공간에 매핑하여 단어 간의 의미적 관계를 나타내는 자연어 처리 기술입니다. 이는 단어의 문맥적 유사성을 기반으로 벡터를 생성합니다.
# 예시: Word2Vec 모델에서 "왕"과 "여왕"은 서로 가까운 위치에 벡터로 표현됩니다.
# 연관키워드: 자연어 처리, 임베딩, 의미론적 유사성
# LLM (Large Language Model)
# =========================================================
# Semantic Search
#
# 정의: 의미론적 검색은 사용자의 질의를 단순한 키워드 매칭을 넘어서 그 의미를 파악하여 관련된 결과를 반환하는 검색 방식입니다.
# 예시: 사용자가 "태양계 행성"이라고 검색하면, "목성", "화성" 등과 같이 관련된 행성에 대한 정보를 반환합니다.
# 연관키워드: 자연어 처리, 검색 알고리즘, 데이터 마이닝
#
# Embedding
# =========================================================
# 정의: 크롤링은 자동화된 방식으로 웹 페이지를 방문하여 데이터를 수집하는 과정입니다. 이는 검색 엔진 최적화나 데이터 분석에 자주 사용됩니다.
# 예시: 구글 검색 엔진이 인터넷 상의 웹사이트를 방문하여 콘텐츠를 수집하고 인덱싱하는 것이 크롤링입니다.
# 연관키워드: 데이터 수집, 웹 스크래핑, 검색 엔진
#
# Word2Vec
# =========================================================

# %% [markdown]
# ### Max Marginal Relevance (MMR)
#
# `MMR(Maximal Marginal Relevance)` 방식은 쿼리에 대한 관련 항목을 검색할 때 검색된 문서의 **중복** 을 피하는 방법 중 하나입니다.
#
# 단순히 가장 관련성 높은 항목들만을 검색하는 대신, MMR은 쿼리에 대한 **문서의 관련성** 과 이미 선택된 **문서들과의 차별성을 동시에 고려** 합니다.

# %% [markdown]
# - `search_type` 매개변수를 `"mmr"` 로 설정하여 **MMR(Maximal Marginal Relevance)** 검색 알고리즘을 사용합니다.
# - `k`: 반환할 문서 수 (기본값: 4)
# - `fetch_k`: MMR 알고리즘에 전달할 문서 수 (기본값: 20)
# - `lambda_mult`: MMR 결과의 다양성 조절 (0~1, 기본값: 0.5, 0: 유사도 점수만 고려, 1: 다양성만 고려)

# %%
# MMR(Maximal Marginal Relevance) 검색 유형을 지정
retriever = db.as_retriever(
    search_type="mmr", search_kwargs={"k": 2, "fetch_k": 10, "lambda_mult": 0.6}
)

# 관련 문서를 검색합니다.
docs = retriever.invoke("임베딩(Embedding)은 무엇인가요?")

# 관련 문서를 검색
for doc in docs:
    print(doc.page_content)
    print("=========================================================")
# Out:
# 정의: 임베딩은 단어나 문장 같은 텍스트 데이터를 저차원의 연속적인 벡터로 변환하는 과정입니다. 이를 통해 컴퓨터가 텍스트를 이해하고 처리할 수 있게 합니다.
# 예시: "사과"라는 단어를 [0.65, -0.23, 0.17]과 같은 벡터로 표현합니다.
# 연관키워드: 자연어 처리, 벡터화, 딥러닝
#
# Token
# =========================================================
# Semantic Search
#
# 정의: 의미론적 검색은 사용자의 질의를 단순한 키워드 매칭을 넘어서 그 의미를 파악하여 관련된 결과를 반환하는 검색 방식입니다.
# 예시: 사용자가 "태양계 행성"이라고 검색하면, "목성", "화성" 등과 같이 관련된 행성에 대한 정보를 반환합니다.
# 연관키워드: 자연어 처리, 검색 알고리즘, 데이터 마이닝
#
# Embedding
# =========================================================

# %% [markdown]
# ### 유사도 점수 임계값 검색(similarity_score_threshold)
#
# 유사도 점수 임계값을 설정하고 해당 임계값 이상의 점수를 가진 문서만 반환하는 검색 방법을 설정할 수 있습니다.
#
# 임계값을 적절히 설정함으로써 **관련성이 낮은 문서를 필터링** 하고, 질의와 **가장 유사한 문서만 선별** 할 수 있습니다.

# %% [markdown]
# - `search_type` 매개변수를 `"similarity_score_threshold"` 로 설정하여 유사도 점수 임계값을 기준으로 검색을 수행합니다.
#
# - `search_kwargs` 매개변수에 `{"score_threshold": 0.8}`를 전달하여 유사도 점수 임계값을 0.8로 설정합니다. 이는 검색 결과의 **유사도 점수가 0.8 이상인 문서만 반환됨** 을 의미합니다.

# %%
retriever = db.as_retriever(
    # 검색 유형을 "similarity_score_threshold 으로 설정
    search_type="similarity_score_threshold",
    # 임계값 설정
    search_kwargs={"score_threshold": 0.8},
)

# 관련 문서를 검색
for doc in retriever.invoke("Word2Vec 은 무엇인가요?"):
    print(doc.page_content)
    print("=========================================================")
# Out:
# 정의: Word2Vec은 단어를 벡터 공간에 매핑하여 단어 간의 의미적 관계를 나타내는 자연어 처리 기술입니다. 이는 단어의 문맥적 유사성을 기반으로 벡터를 생성합니다.
# 예시: Word2Vec 모델에서 "왕"과 "여왕"은 서로 가까운 위치에 벡터로 표현됩니다.
# 연관키워드: 자연어 처리, 임베딩, 의미론적 유사성
# LLM (Large Language Model)
# =========================================================

# %% [markdown]
# ### top_k 설정
#
# 검색 시 사용할 `k` 와 같은 검색 키워드 인자(kwargs)를 지정할 수 있습니다.
#
# `k` 매개변수는 검색 결과에서 반환할 상위 결과의 개수를 나타냅니다.

# %% [markdown]
# - `search_kwargs`에서 `k` 매개변수를 1로 설정하여 검색 결과로 반환할 문서의 수를 지정합니다.

# %%
# k 설정
retriever = db.as_retriever(search_kwargs={"k": 1})

# 관련 문서를 검색
docs = retriever.invoke("임베딩(Embedding)은 무엇인가요?")

# 관련 문서를 검색
for doc in docs:
    print(doc.page_content)
    print("=========================================================")
# Out:
# 정의: 임베딩은 단어나 문장 같은 텍스트 데이터를 저차원의 연속적인 벡터로 변환하는 과정입니다. 이를 통해 컴퓨터가 텍스트를 이해하고 처리할 수 있게 합니다.
# 예시: "사과"라는 단어를 [0.65, -0.23, 0.17]과 같은 벡터로 표현합니다.
# 연관키워드: 자연어 처리, 벡터화, 딥러닝
#
# Token
# =========================================================

# %% [markdown]
# ## 동적 설정(Configurable)
#
# - 검색 설정을 동적으로 조정하기 위해 `ConfigurableField` 를 사용합니다.
# - `ConfigurableField` 는 검색 매개변수의 고유 식별자, 이름, 설명을 설정하는 역할을 합니다.
# - 검색 설정을 조정하기 위해 `config` 매개변수를 사용하여 검색 설정을 지정합니다.
# - 검색 설정은 `config` 매개변수에 전달된 딕셔너리의 `configurable` 키에 저장됩니다.
# - 검색 설정은 검색 쿼리와 함께 전달되며, 검색 쿼리에 따라 동적으로 조정됩니다.

# %%
from langchain_core.runnables import ConfigurableField

# k 설정
retriever = db.as_retriever(search_kwargs={"k": 1}).configurable_fields(
    search_type=ConfigurableField(
        id="search_type",
        name="Search Type",
        description="The search type to use",
    ),
    search_kwargs=ConfigurableField(
        # 검색 매개변수의 고유 식별자를 설정
        id="search_kwargs",
        # 검색 매개변수의 이름을 설정
        name="Search Kwargs",
        # 검색 매개변수에 대한 설명을 작성
        description="The search kwargs to use",
    ),
)

# %% [markdown]
# 아래는 동적 검색설정을 적용한 예시입니다.

# %%
# 검색 설정을 지정. Faiss 검색에서 k=3로 설정하여 가장 유사한 문서 3개를 반환
config = {"configurable": {"search_kwargs": {"k": 3}}}

# 관련 문서를 검색
docs = retriever.invoke("임베딩(Embedding)은 무엇인가요?", config=config)

# 관련 문서를 검색
for doc in docs:
    print(doc.page_content)
    print("=========================================================")
# Out:
# 정의: 임베딩은 단어나 문장 같은 텍스트 데이터를 저차원의 연속적인 벡터로 변환하는 과정입니다. 이를 통해 컴퓨터가 텍스트를 이해하고 처리할 수 있게 합니다.
# 예시: "사과"라는 단어를 [0.65, -0.23, 0.17]과 같은 벡터로 표현합니다.
# 연관키워드: 자연어 처리, 벡터화, 딥러닝
#
# Token
# =========================================================
# 정의: Word2Vec은 단어를 벡터 공간에 매핑하여 단어 간의 의미적 관계를 나타내는 자연어 처리 기술입니다. 이는 단어의 문맥적 유사성을 기반으로 벡터를 생성합니다.
# 예시: Word2Vec 모델에서 "왕"과 "여왕"은 서로 가까운 위치에 벡터로 표현됩니다.
# 연관키워드: 자연어 처리, 임베딩, 의미론적 유사성
# LLM (Large Language Model)
# =========================================================
# Semantic Search
#
# 정의: 의미론적 검색은 사용자의 질의를 단순한 키워드 매칭을 넘어서 그 의미를 파악하여 관련된 결과를 반환하는 검색 방식입니다.
# 예시: 사용자가 "태양계 행성"이라고 검색하면, "목성", "화성" 등과 같이 관련된 행성에 대한 정보를 반환합니다.
# 연관키워드: 자연어 처리, 검색 알고리즘, 데이터 마이닝
#
# Embedding
# =========================================================

# %%
# 검색 설정을 지정. score_threshold 0.8 이상의 점수를 가진 문서만 반환
config = {
    "configurable": {
        "search_type": "similarity_score_threshold",
        "search_kwargs": {
            "score_threshold": 0.8,
        },
    }
}

# 관련 문서를 검색
docs = retriever.invoke("Word2Vec 은 무엇인가요?", config=config)

# 관련 문서를 검색
for doc in docs:
    print(doc.page_content)
    print("=========================================================")
# Out:
# 정의: Word2Vec은 단어를 벡터 공간에 매핑하여 단어 간의 의미적 관계를 나타내는 자연어 처리 기술입니다. 이는 단어의 문맥적 유사성을 기반으로 벡터를 생성합니다.
# 예시: Word2Vec 모델에서 "왕"과 "여왕"은 서로 가까운 위치에 벡터로 표현됩니다.
# 연관키워드: 자연어 처리, 임베딩, 의미론적 유사성
# LLM (Large Language Model)
# =========================================================

# %%
# 검색 설정을 지정. mmr 검색 설정.
config = {
    "configurable": {
        "search_type": "mmr",
        "search_kwargs": {"k": 2, "fetch_k": 10, "lambda_mult": 0.6},
    }
}

# 관련 문서를 검색
docs = retriever.invoke("Word2Vec 은 무엇인가요?", config=config)

# 관련 문서를 검색
for doc in docs:
    print(doc.page_content)
    print("=========================================================")
# Out:
# 정의: Word2Vec은 단어를 벡터 공간에 매핑하여 단어 간의 의미적 관계를 나타내는 자연어 처리 기술입니다. 이는 단어의 문맥적 유사성을 기반으로 벡터를 생성합니다.
# 예시: Word2Vec 모델에서 "왕"과 "여왕"은 서로 가까운 위치에 벡터로 표현됩니다.
# 연관키워드: 자연어 처리, 임베딩, 의미론적 유사성
# LLM (Large Language Model)
# =========================================================
# 정의: 크롤링은 자동화된 방식으로 웹 페이지를 방문하여 데이터를 수집하는 과정입니다. 이는 검색 엔진 최적화나 데이터 분석에 자주 사용됩니다.
# 예시: 구글 검색 엔진이 인터넷 상의 웹사이트를 방문하여 콘텐츠를 수집하고 인덱싱하는 것이 크롤링입니다.
# 연관키워드: 데이터 수집, 웹 스크래핑, 검색 엔진
#
# Word2Vec
# =========================================================

# %% [markdown]
# ## Upstage 임베딩과 같이 Query & Passage embedding model 이 분리된 경우
#
# 기본 retriever는 쿼리와 문서에 대해 동일한 임베딩 모델을 사용합니다.
#
# 하지만 쿼리와 문서에 대해 서로 다른 임베딩 모델을 사용하는 경우가 있습니다.
#
# 이러한 경우에는 쿼리 임베딩 모델을 사용하여 쿼리를 임베딩하고, 문서 임베딩 모델을 사용하여 문서를 임베딩합니다.
#
# 이렇게 하면 쿼리와 문서에 대해 서로 다른 임베딩 모델을 사용할 수 있습니다.

# %%
from langchain_community.vectorstores import FAISS
from langchain_text_splitters import CharacterTextSplitter
from langchain_community.document_loaders import TextLoader
from langchain_upstage import UpstageEmbeddings

# TextLoader를 사용하여 파일을 로드합니다.
loader = TextLoader("./data/appendix-keywords.txt")

# 문서를 로드합니다.
documents = loader.load()

# 문자 기반으로 텍스트를 분할하는 CharacterTextSplitter를 생성합니다. 청크 크기는 300이고 청크 간 중복은 없습니다.
text_splitter = CharacterTextSplitter(chunk_size=300, chunk_overlap=0)

# 로드된 문서를 분할합니다.
split_docs = text_splitter.split_documents(documents)

# Upstage 임베딩을 생성합니다. 문서용 모델을 사용합니다.
doc_embedder = UpstageEmbeddings(model="solar-embedding-1-large-passage")

# 분할된 텍스트와 임베딩을 사용하여 FAISS 벡터 데이터베이스를 생성합니다.
db = FAISS.from_documents(split_docs, doc_embedder)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 4
#       2 from langchain_text_splitters import CharacterTextSplitter
#       3 from langchain_community.document_loaders import TextLoader
# ----> 4 from langchain_upstage import UpstageEmbeddings
#       6 # TextLoader를 사용하여 파일을 로드합니다.
#       7 loader = TextLoader("./data/appendix-keywords.txt")
#
# ModuleNotFoundError: No module named 'langchain_upstage'

# %% [markdown]
# 아래는 쿼리용 Upstage 임베딩을 생성하고, 쿼리 문장을 벡터로 변환하여 벡터 유사도 검색을 수행하는 예시입니다.

# %%
# 쿼리용 Upstage 임베딩을 생성합니다. 쿼리용 모델을 사용합니다.
query_embedder = UpstageEmbeddings(model="solar-embedding-1-large-query")

# 쿼리 문장을 벡터로 변환합니다.
query_vector = query_embedder.embed_query("임베딩(Embedding)은 무엇인가요?")

# 벡터 유사도 검색을 수행하여 가장 유사한 2개의 문서를 반환합니다.
db.similarity_search_by_vector(query_vector, k=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 # 쿼리용 Upstage 임베딩을 생성합니다. 쿼리용 모델을 사용합니다.
# ----> 2 query_embedder = UpstageEmbeddings(model="solar-embedding-1-large-query")
#       4 # 쿼리 문장을 벡터로 변환합니다.
#       5 query_vector = query_embedder.embed_query("임베딩(Embedding)은 무엇인가요?")
#
# NameError: name 'UpstageEmbeddings' is not defined
