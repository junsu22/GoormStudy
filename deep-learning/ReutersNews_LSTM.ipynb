# %%
# LSTM 으로 로이터 뉴스 분류하기


# LSTM 으로 로이터 뉴스 분류하기

import numpy as np
import tensorflow as tf

from tensorflow.keras.datasets import reuters
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

embedding_dim = 128
hidden_units = 128
num_classes = 46
vocab_size = 10000
max_len = 100

# 데이터 불러오기
(X_train, y_train), (X_test, y_test) = reuters.load_data(num_words=vocab_size)

# 문장 길이 맞추기
X_train = pad_sequences(X_train, maxlen=max_len)
X_test = pad_sequences(X_test, maxlen=max_len)

# 모델 생성
model = Sequential()
model.add(Embedding(vocab_size, embedding_dim, input_length=max_len))
model.add(LSTM(hidden_units))
model.add(Dense(num_classes, activation='softmax'))

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=4)
mc = ModelCheckpoint('best_model.keras', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

# 컴파일
model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# 학습
history = model.fit(
    X_train, y_train,
    batch_size=128,
    epochs=30,
    callbacks=[es, mc],
    validation_data=(X_test, y_test)
)
# Out:
# Epoch 1/30
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - accuracy: 0.3270 - loss: 2.9245
# Epoch 1: val_accuracy improved from -inf to 0.48442, saving model to best_model.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 30s 389ms/step - accuracy: 0.3276 - loss: 2.9187 - val_accuracy: 0.4844 - val_loss: 2.0579
# Epoch 2/30
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.4870 - loss: 1.9774
# Epoch 2: val_accuracy improved from 0.48442 to 0.51158, saving model to best_model.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 27s 377ms/step - accuracy: 0.4872 - loss: 1.9765 - val_accuracy: 0.5116 - val_loss: 1.9173
# Epoch 3/30
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.5073 - loss: 1.8324
# Epoch 3: val_accuracy improved from 0.51158 to 0.52226, saving model to best_model.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 27s 388ms/step - accuracy: 0.5076 - loss: 1.8314 - val_accuracy: 0.5223 - val_loss: 1.8050
# Epoch 4/30
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.5474 - loss: 1.7184
# Epoch 4: val_accuracy improved from 0.52226 to 0.56545, saving model to best_model.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 27s 383ms/step - accuracy: 0.5476 - loss: 1.7177 - val_accuracy: 0.5654 - val_loss: 1.7093
# Epoch 5/30
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.5835 - loss: 1.6133
# Epoch 5: val_accuracy improved from 0.56545 to 0.61665, saving model to best_model.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 27s 376ms/step - accuracy: 0.5837 - loss: 1.6127 - val_accuracy: 0.6167 - val_loss: 1.6408
# Epoch 6/30
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.6442 - loss: 1.4349
# Epoch 6: val_accuracy improved from 0.61665 to 0.63713, saving model to best_model.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 27s 375ms/step - accuracy: 0.6443 - loss: 1.4344 - val_accuracy: 0.6371 - val_loss: 1.5180
# Epoch 7/30
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 0.6855 - loss: 1.2561
# Epoch 7: val_accuracy did not improve from 0.63713
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 29s 407ms/step - accuracy: 0.6856 - loss: 1.2559 - val_accuracy: 0.6362 - val_loss: 1.4592
# Epoch 8/30
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.7141 - loss: 1.1048
# Epoch 8: val_accuracy improved from 0.63713 to 0.64737, saving model to best_model.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 27s 377ms/step - accuracy: 0.7143 - loss: 1.1044 - val_accuracy: 0.6474 - val_loss: 1.4488
# Epoch 9/30
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - accuracy: 0.7563 - loss: 0.9623
# Epoch 9: val_accuracy improved from 0.64737 to 0.65227, saving model to best_model.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 27s 380ms/step - accuracy: 0.7564 - loss: 0.9620 - val_accuracy: 0.6523 - val_loss: 1.4394
# Epoch 10/30
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.8047 - loss: 0.8026
# Epoch 10: val_accuracy improved from 0.65227 to 0.67231, saving model to best_model.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 28s 394ms/step - accuracy: 0.8046 - loss: 0.8027 - val_accuracy: 0.6723 - val_loss: 1.4256
# Epoch 11/30
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.8090 - loss: 0.7371
# Epoch 11: val_accuracy improved from 0.67231 to 0.68121, saving model to best_model.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 27s 385ms/step - accuracy: 0.8092 - loss: 0.7367 - val_accuracy: 0.6812 - val_loss: 1.4307
# Epoch 12/30
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 0.8534 - loss: 0.5952
# Epoch 12: val_accuracy improved from 0.68121 to 0.69145, saving model to best_model.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 27s 377ms/step - accuracy: 0.8534 - loss: 0.5952 - val_accuracy: 0.6915 - val_loss: 1.4201
# Epoch 13/30
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.8760 - loss: 0.4854
# Epoch 13: val_accuracy did not improve from 0.69145
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 41s 378ms/step - accuracy: 0.8759 - loss: 0.4858 - val_accuracy: 0.6892 - val_loss: 1.4036
# Epoch 14/30
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.8895 - loss: 0.4429
# Epoch 14: val_accuracy improved from 0.69145 to 0.70169, saving model to best_model.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 41s 377ms/step - accuracy: 0.8896 - loss: 0.4428 - val_accuracy: 0.7017 - val_loss: 1.4285
# Epoch 15/30
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - accuracy: 0.9167 - loss: 0.3576
# Epoch 15: val_accuracy did not improve from 0.70169
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 27s 380ms/step - accuracy: 0.9166 - loss: 0.3578 - val_accuracy: 0.6941 - val_loss: 1.5487
# Epoch 16/30
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.9097 - loss: 0.3530
# Epoch 16: val_accuracy did not improve from 0.70169
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 27s 378ms/step - accuracy: 0.9098 - loss: 0.3528 - val_accuracy: 0.6995 - val_loss: 1.5610
# Epoch 17/30
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - accuracy: 0.9142 - loss: 0.3256
# Epoch 17: val_accuracy did not improve from 0.70169
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 27s 379ms/step - accuracy: 0.9143 - loss: 0.3254 - val_accuracy: 0.7012 - val_loss: 1.5312
# Epoch 17: early stopping

# %%
# LSTM으로 로이터 뉴스 분류
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.dataset
